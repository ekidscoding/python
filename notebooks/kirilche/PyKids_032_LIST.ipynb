# %% [markdown]
# # Списки
#
# Списки - це такі змінні, що можуть **містити**:
# *   нічого (порожній список) `[]`
# *   1 елемент будь-якого типу `[1024]`, `["Mykyta"]`, `[("Ukraine", "Kyiv")]`
# *   2+ елементів будь-якого типу `[1024, 365]`, `["Mykyta", "Орися", "😀"]`, `[("Ukraine", "Kyiv", 482), ("India", "New Delhi", 1931), ("Georgia", "Tbilisi", 455)]`
#
# `in` - це оператор, що перевіряє чи міститься деяке значення у списку.

# %%
teachers = []

print(teachers)

print("Kiril" in teachers)
# Out:
# []
# False

# %% [markdown]
# # append()
#
# Append (додати) - це операція додавання елементу до списку.

# %%
teachers.append("Kiril")

print(teachers)

print("Kiril" in teachers)
# Out:
# ['Kiril']
# True

# %% [markdown]
# # extend()
#
# Extend (розширити, подовжити) - це операція додавання ВСІХ елементів одного списку до іншого списку. Або іншими словами extend - це **злиття** списків

# %%
teachers_2024 = ["Kiril", "Daryna"]
teachers_2021 = ["Anton", "Ark"]
# створимо ПСЕВДОНІМ першого списку
teachers_2025 = teachers_2024

teachers_2025.extend(teachers_2021)
print(f"{teachers_2025=}")
# Out:
# teachers_2025=['Kiril', 'Daryna', 'Anton', 'Ark']

# %% [markdown]
# 🟠УВАГА код вгорі змінить також `teachers_2024`, бо `teachers_2025` - це всього лиш **псевдонім** для `teachers_2024`

# %%
print(f"{teachers_2024=}")
# Out:
# teachers_2024=['Kiril', 'Daryna', 'Anton', 'Ark']

# %% [markdown]
# # copy()
#
# Щоб не траплялося так, що ми ненароком змінили вихідний список, можна змінити один рядок

# %%
teachers_2024 = ["Kiril", "Daryna"]
teachers_2021 = ["Anton", "Ark"]
# створимо КОПІЮ першого списку
teachers_2025 = teachers_2024.copy()

teachers_2025.extend(teachers_2021)
print(f"{teachers_2025=}")
print(f"{teachers_2024=}")
# Out:
# teachers_2025=['Kiril', 'Daryna', 'Anton', 'Ark']
# teachers_2024=['Kiril', 'Daryna']

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # remove()
#
# Видалення елемента за його значенням

# %%
teachers_2025.remove('Ark')
print(f"{teachers_2025=}")
# Out:
# teachers_2025=['Kiril', 'Daryna', 'Anton']

# %% [markdown]
# # del
#
# Видалення елемента за його індексом
#
#
#
# > Індекс - це порядковий номер, починаючи з 0

# %%
del teachers_2025[1]
print(f"{teachers_2025=}")
# Out:
# teachers_2025=['Kiril', 'Anton']

# %% [markdown]
# # pop()
#
# Операція `pop()` дозволяє одночасно видалити елемент та повернути значення цього елементу.

# %%
черга_на_нагородження = ["Василь", "Галина", "Святослав", "Нестор"]

while черга_на_нагородження != []:
  людинка = черга_на_нагородження.pop()
  print("Листом подяки нагороджується", людинка)

print("Всіх нагородили")
# Out:
# Листом подяки нагороджується Нестор
# Листом подяки нагороджується Святослав
# Листом подяки нагороджується Галина
# Листом подяки нагороджується Василь
# Всіх нагородили

# %% [markdown]
# # index()

# %%
teachers_2021 = ["Anton", "Ark"]

if "Ark" in teachers_2021:
  ark_index = teachers_2021.index("Ark")
  message = f'''
  Аркадій знаходиться у списку вчителів
  {teachers_2021=}
  під номером {ark_index}, або
  якщо рахувати як звичайні люди,
  то він {ark_index+1}й"
  '''
  print(message)
# Out:
#   Аркадій знаходиться у списку вчителів
#   teachers_2021=['Anton', 'Ark']
#   під номером 1, або
#   якщо рахувати як звичайні люди,
#   то він 2й"

# %% [markdown]
# # insert()
#
# Вставити у список елемент у обрану позицію. Наприклад не в кінець, а в початок.

# %%
teachers_2025 = ['Kiril', 'Anton']

teachers_2025.insert(0, "Mykola")
print(f"{teachers_2025=}")
# Out:
# teachers_2025=['Mykola', 'Kiril', 'Anton']

# %% [markdown]
# # count()
#
# Підраховує кількість входжень елемента у список.

# %%
імена = ["Міша", "Єва", "Саша", "Оля", "Міша"]

print(імена.count("Міша"))
# Out:
# 2

# %% [markdown]
# # sort()

# %%
імена = ["Міша", "Єва", "Саша", "Оля", "Міша"]
імена.sort()
print(імена)
# Out:
# ['Єва', 'Міша', 'Міша', 'Оля', 'Саша']

# %% [markdown]
# # reverse()

# %%
черга_на_нагородження = ["Василь", "Галина", "Святослав", "Нестор"]

черга_на_нагородження.reverse()

while черга_на_нагородження != []:
  людинка = черга_на_нагородження.pop()
  print("Листом подяки нагороджується", людинка)

print("Всіх нагородили")
# Out:
# Листом подяки нагороджується Василь
# Листом подяки нагороджується Галина
# Листом подяки нагороджується Святослав
# Листом подяки нагороджується Нестор
# Всіх нагородили
