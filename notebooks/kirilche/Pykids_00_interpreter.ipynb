# %% [markdown]
# # Вітаємо в світі програмування
#
# Програмування - це така "гра" коли ви пишете текст на мові, зрозумілій інтерпретатору (чи компілятору).
#
# Прикладом інтерпретатора є сама програма **Python** (CPython, якщо бути точними).
#
# Інтерпретатор написаний вже дуже [давно](https://uk.wikipedia.org/wiki/Python#%D0%86%D1%81%D1%82%D0%BE%D1%80%D1%96%D1%8F) і з тих давніх пір навчився багато чого. З кожним релізом (версією) сам інтерпретатор стає швидшим та потужнішим.
#
# > Виникають інші молоді мови, що побудовані на мові Python (такі як [Mojo](https://www.modular.com/mojo)).
#
# Python може працювати в 2 режимах.
#
# **Інтерактивний** режим - це коли ви просто запускаєте сам інтерпретатор. А далі вже всередині нього запускаєте інструкції крок за кроком. Коли ви завершуєте сеанс - пишете quit(), або натискаєте CTRL+D.
#
# > В Пайтон 3.13+ також працює команда quit без дужок.
#
# Не-інтерактивний (або просто **звичайний**) режим роботи інтерпретатора - це коли ми виконуємо скрипт або програму, яка в свою чергу "під капотом" викликає інші програми (або підпрограми) чи функції.
#
# Ще є третій, особливий режим -- **Jupyter**. Але це вже не режим інтерпретатора, а окрема програма, яка може виглядати спершу як інтерактивний режим "на стероїдах" 💪

# %% [markdown]
# # Comments (коментарі)
# В будь-якій поширеній мові програмування є спосіб писати текст, який ігнорується інтерпретатором. В мові Пайтон є така домовленність
#
#
# > Все, що починається знаком # і до кінця рядка - це для людей. Інтерпретатор слухняно пропустить все, що там написано.
#
# Щоправда є виключення. Якщо # потрапить всередину рядкового літералу (str) то він не подіє на інтерпретатор. Інтерпретатор продовжить читати цей рядок далі.
#
# Якщо ви запустите комірку на виконання, то побачите вивід.

# %%
1
# Out:
# 1

# %% [markdown]
# Наступна комірка не виведе нічого

# %%
# 2

# %% [markdown]
# # Примітки
# Так в середовищі **Jupyter** та **Google Colab** якщо ви вводите будь-який вираз у комірку - ви отримуєте його значення у виводі нижче. Якщо вираз відсутній - виводу ви не побачите.
#
# Інструкції інтерпретатору не є виразами.
#
# Коментар (знак # і все що за ним до кінця рядку) - це не вираз. Тому і виводу не матиме.
#
# Якщо ж ви спробуєте виконати програму, в якій є лише цифра або ще якийсь тривіальний вираз за допомогою інтерпретатора у його **звичайному** режимі, то не отримаєте нічого.
#
#
# > Це як речення без присудку. Без дії.
#
# Запустивши **інтерактивний** режим, ви побачите поведінку схожу на те, як поводить себе Jupyter/Colab
#
# $ python
#
# Python 3.12.5 (v3.12.5:ff3bc82f7c9, Aug  7 2024, 05:32:06) [Clang 13.0.0 (clang-1300.0.29.30)] on darwin
# Type "help", "copyright", "credits" or "license" for more information.
#
# \>\>\> 1
#
# 1

# %% [markdown]
# # Home Task
#
#
#
# > NOT Jupyter/Colab
#
#
# 0.   Якщо ви працюєте на MacOS, Linux чи подібній системі виконайте `alias py=python3`
# 1.   Запустити `python`, який встановлений в системі (якщо це MacOS або Linux)
# 2.   Запустити `py`
# 4.   Запустити `py -V` (велика літера)
# 5.   Запустити `py --version` (два дифіса та всі малі літери)
# 6.   Запустити `py -q` (quiet mode)
# 7.   Запустити `py -h` (-? --help)
#
#
# ---
#
#
# # Задача з *
#
#
# *   Запустити існуючий скрипт за допомогою `py -i script_name.py`
# *   Запустити `py -c "import this"`
#
#
# ---
#
# # Задача з **
#
#
# *   `py -m timeit "for _ in range(1_000_000): ..."`
# *   `py -m pip install -U pip`
